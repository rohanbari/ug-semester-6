# %% [markdown]
# # Class 1 Experiments (c1_1 to c1_6)
# This notebook combines the scripts from `c1_1.py` through `c1_6.py`.

# %%
def sum() -> None:
    """Sum of two numbers by user input"""

    num1 = int(input("Enter the 1st number: "))
    num2 = int(input("Enter the 2nd number: "))

    print("Sum of two numbers:", num1 + num2)


if __name__ == "__main__":
    sum()

# %% [markdown]
# ## c1_2.py

# %%
# Conditions in Python

def isEvenOdd(num) -> None:
    if num % 2 == 0:
        print("The number is even.")
    else:
        print("The number is odd.")


def isEvenOdd2(num) -> None:
    isEven = num % 2 == 0
    print("The number", num, "is", "even." if isEven else "odd.")


def main():
    # Python program to check if a number is even or odd
    num = int(input("Input a number: "))

    isEvenOdd(num)
    isEvenOdd2(num)


if __name__ == "__main__":
    main()

# %% [markdown]
# ## c1_3.py

# %%
# Loops in Python

def sumNums(num: int) -> None:
    currSum = 0
    for i in range(1, num + 1):
        currSum += i

    print("Sum from 1 to", num, "is:", currSum)


def sumNums2(num: int) -> None:
    currSum = sum([n for n in range(1, num + 1)])
    print(f"Sum of first {num} natural numbers is:", currSum)


def sumWhile(num: int) -> None:
    currSum = 0
    while num > 0:
        currSum += num
        num -= 1

    print(f"Sum of first {num} natural numbers:", currSum)


def main() -> None:
    N = int(input("Input the value of N: "))
    sumNums(N)
    sumNums2(N)
    sumWhile(N)


if __name__ == "__main__":
    main()

# %% [markdown]
# ## c1_4.py

# %%
# Swapping b/w two numbers without a third variable
num1 = int(input("Input the 1st number: "))
num2 = int(input("Input the 2nd number: "))

print(f"Before swap: {num1}, {num2}")

num1 = num1 + num2
num2 = num1 - num2
num1 = num1 - num2

print(f"After swap: {num1}, {num2}")

# %% [markdown]
# ## c1_5.py

# %%
N = int(input("Enter a number: "))

if N < 0:
    print("It is not an Armstrong number.")
    exit(0)

original = N
digits = len(str(N))
total = 0

while N > 0:
    digit = N % 10
    total += digit ** digits
    N //= 10

# For input 0, loop won't run; 0 is Armstrong
if original == 0:
    total = 0

# Using ternary operator to cover four lines in a Pythonic way
print(f"It is {"" if total == original else "not "}an Armstrong number.")

# %% [markdown]
# ## c1_6.py

# %%
"""Compute factorial of a non-negative integer."""

num = int(input("Input a number: "))

result = 1
for i in range(2, num + 1):
    result *= i

print(f"Factorial of {num} is {result}.")
